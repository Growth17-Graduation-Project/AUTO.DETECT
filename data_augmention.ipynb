# %%
import numpy as np # linear algebra
import pandas as pd
from google.colab import drive
drive.mount('./content')
# Out:
# Mounted at ./content

# %%
from PIL import Image
from glob import glob
import numpy as np


img_list = glob('/content/content/MyDrive/졸업프로젝트(개인관리)/before_augmentation/*.jpg')
print(len(img_list))
count=0
for i in img_list:
  count=count+1
  img=Image.open(i)
  area=(100,100,1000,1200)
  cropped_img=img.crop(area)
  cropped_img=cropped_img.convert('RGB')
  cropped_img.save('/content/content/MyDrive/졸업프로젝트(개인관리)/new/'+str(count)+'.jpg')
# Out:
# 1775

# %%
cp -a /content/content/MyDrive/GP_personal/after_augmentation_crop/. /content/content/MyDrive/GP_personal/v4_dataset/

# %%
from glob import glob
import numpy as np
img_list = glob('/content/content/MyDrive/GP_personal/after_augmentation_n(b+c)/*.jpg')
print(len(img_list))
# Out:
# 741

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
img_list = glob('/content/content/MyDrive/GP_personal/v4_dataset/*.jpg')
img_list=img_list[635:]
print(len(img_list))

count=636
for i in img_list:
  count=count+1

  img = cv2.imread(i)[...,::-1]/255.0
  noise =  np.random.normal(loc=0, scale=1, size=img.shape)

# noise overlaid over image
  noisy = np.clip((img + noise*0.1),0,1)
  noisy2 = np.clip((img + noise*0.3),0,1)

# noise multiplied by image:
# whites can go to black but blacks cannot go to white
  noisy2mul = np.clip((img*(1 + noise*0.1)),0,1)
  noisy4mul = np.clip((img*(1 + noise*0.3)),0,1)

  noisy2mul = np.clip((img*(1 + noise*0.1)),0,1)
  noisy4mul = np.clip((img*(1 + noise*0.3)),0,1)

# noise multiplied by bottom and top half images,
# whites stay white blacks black, noise is added to center
  img2 = img*2
  n2 = np.clip(np.where(img2 <= 1, (img2*(1 + noise*0.2)), (1-img2+1)*(1 + noise*0.2)*-1 + 2)/2, 0,1)
  n4 = np.clip(np.where(img2 <= 1, (img2*(1 + noise*0.4)), (1-img2+1)*(1 + noise*0.4)*-1 + 2)/2, 0,1)


# norm noise for viz only
  noise2 = (noise - noise.min())/(noise.max()-noise.min())
  plt.figure(figsize=(20,20))
  plt.imshow(np.vstack((
                      np.hstack((noisy2mul, noisy4mul)),
  )))
  plt.savefig('/content/content/MyDrive/GP_personal/after_augmentation_n(b+c)/'+str(count)+'n.jpg')
# Out:
# 2914
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
from glob import glob
import numpy as np
img_list = glob('/content/content/MyDrive/GP_personal/img/*.jpg')
print(len(img_list))
# Out:
# 1539

# %%
import os

file_path = '/content/content/MyDrive/GP_personal/img'
file_names = os.listdir(file_path)
len(file_names)
# Out:
# 1539

# %%
i = 1
for name in img_list:
    src = os.path.join(file_path, name)
    dst = str(i) + 'crop.jpg'
    dst = os.path.join(file_path, dst)
    os.rename(src, dst)
    i += 1

# %%
pip install -q tf-nightly
# Out:
#      |████████████████████████████████| 455.4MB 31kB/s
#      |████████████████████████████████| 1.2MB 39.9MB/s
#      |████████████████████████████████| 4.0MB 12.2MB/s
#      |████████████████████████████████| 471kB 46.7MB/s
#      |████████████████████████████████| 4.0MB 46.2MB/s
#      |████████████████████████████████| 6.0MB 40.9MB/s
#      |████████████████████████████████| 3.9MB 43.9MB/s
# ERROR: tensorflow 2.4.1 has requirement gast==0.3.3, but you'll have gast 0.4.0 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement grpcio~=1.32.0, but you'll have grpcio 1.34.1 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement h5py~=2.10.0, but you'll have h5py 3.1.0 which is incompatible.

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from tensorflow.keras import layers

# %%
imgs = glob('/content/content/MyDrive/HFSP/certain_mono/100certain_mono.jpg')

IMG_SIZE=180
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255)
])

img=load_img(imgs)
data=img_to_array(img)
samples=expand_dims(data,0)
result = resize_and_rescale(samples)
_ = plt.imshow(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1fa2398a6ebe> in <module>()
#       9 ])
#      10
# ---> 11 img=load_img(imgs)
#      12 data=img_to_array(img)
#      13 samples=expand_dims(data,0)
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     291   """
#     292   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 293                         target_size=target_size, interpolation=interpolation)
#     294
#     295
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# ...
